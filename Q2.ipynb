# %% [markdown]
# <h1 align="center">Introduction to Machine Learning - Course Code: 25737</h1>
# <h4 align="center">Instructor: Dr. Amiri</h4>
# <h4 align="center">Sharif University of Technology, Spring 2024</h4>
# <h4 align="center">Computer Assignment 3</h4>
# <h4 align="center">
#
# Question 2
#
# </h4>

# %% [markdown]
# # Personal Data

# %%
# Set your student number
student_number = 400101861
Name = 'ahmadreza'
Last_Name = 'majlesara'

# %% [markdown]
# # Rules
# - You are not allowed to add or remove cells. You **must use the provided space to write your code**. If you don't follow this rule, **your Practical Assignment won't be graded**.
#
# - Collaboration and using the internet is allowed, but your code **must be written by yourself**. **Copying code** from each other or from available resources will result in a **zero score for the assignment**.
#
# - You are not allowed to use `torch.nn`, `torch.optim` and any activation function and loss function implemented in torch.

# %% [markdown]
# ## Question 1) Convolutional Neural Networks ``(50 pt.)``
#
# In this question, you'll be coding up a convolutional neural network from scratch to classify images using PyTorch.
#
# ### Instructions
# - Install PyTorch following the instructions [here](https://pytorch.org/).
# - Install the [`torchinfo` package](https://github.com/TylerYep/torchinfo) to visualize the network architecture and the number of parameters. The maximum number of parameters you are allowed to use for your network is **100,000**.
# - You are required to complete the functions defined in the code blocks following each question. Fill out sections of the code marked `"YOUR CODE HERE"`.
# - You're free to add any number of methods within each class.
# - You may also add any number of additional code blocks that you deem necessary.

# %% [markdown]
# ### Data Preparation
# In this assignment, we will use the Fashion-MNIST dataset. Fashion-MNIST is a dataset of Zalando's article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes.
#
# #### Data
#
# Each image is 28 pixels in height and 28 pixels in width, for a total of 784 pixels in total. Each pixel has a single pixel-value associated with it, indicating the lightness or darkness of that pixel, with higher numbers meaning darker. This pixel-value is an integer between 0 and 255.
#
# #### Labels
#
# Each training and test example is assigned to one of the following labels:
#
# | Label | Description |
# |-------|-------------|
# | 0     | T-shirt/top |
# | 1     | Trouser     |
# | 2     | Pullover    |
# | 3     | Dress       |
# | 4     | Coat        |
# | 5     | Sandal      |
# | 6     | Shirt       |
# | 7     | Sneaker     |
# | 8     | Bag         |
# | 9     | Ankle boot  |
#
# Fashion-MNIST is included in the `torchvision` library.

# %%
# !pip install torchinfo
# !pip install torch
# Out:
# Requirement already satisfied: torchinfo in c:\users\digi max\appdata\local\programs\python\python39\lib\site-packages (1.8.0)
# WARNING: You are using pip version 21.1.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\users\digi max\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: torch in c:\users\digi max\appdata\local\programs\python\python39\lib\site-packages (2.3.0)
# Requirement already satisfied: jinja2 in c:\users\digi max\appdata\local\programs\python\python39\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: sympy in c:\users\digi max\appdata\local\programs\python\python39\lib\site-packages (from torch) (1.12.1)
# Requirement already satisfied: fsspec in c:\users\digi max\appdata\local\programs\python\python39\lib\site-packages (from torch) (2024.5.0)
# Requirement already satisfied: networkx in c:\users\digi max\appdata\local\programs\python\python39\lib\site-packages (from torch) (3.2.1)
# Requirement already satisfied: filelock in c:\users\digi max\appdata\local\programs\python\python39\lib\site-packages (from torch) (3.14.0)
# Requirement already satisfied: mkl<=2021.4.0,>=2021.1.1 in c:\users\digi max\appdata\local\programs\python\python39\lib\site-packages (from torch) (2021.4.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\digi max\appdata\roaming\python\python39\site-packages (from torch) (4.8.0)
# Requirement already satisfied: tbb==2021.* in c:\users\digi max\appdata\local\programs\python\python39\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.12.0)
# Requirement already satisfied: intel-openmp==2021.* in c:\users\digi max\appdata\local\programs\python\python39\lib\site-packages (from mkl<=2021.4.0,>=2021.1.1->torch) (2021.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\digi max\appdata\local\programs\python\python39\lib\site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in c:\users\digi max\appdata\local\programs\python\python39\lib\site-packages (from sympy->torch) (1.3.0)
# WARNING: You are using pip version 21.1.3; however, version 24.0 is available.
# You should consider upgrading via the 'c:\users\digi max\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# Import required packages
from torchvision.datasets import FashionMNIST
from torchvision.transforms import Compose, ToTensor, Normalize
import matplotlib.pyplot as plt
import numpy as np 
import torchvision.utils as vutils
import seaborn as sns
import pandas as pd

# %%
# Transform to normalize the data and convert to a tensor
transform = Compose([ToTensor(), Normalize((0.5,), (0.5,))])

# Download the data
dataset = FashionMNIST('MNIST_data/', download = True, train = True, transform = transform)

# %% [markdown]
# ### Data Exploration
# Let's take a look at the classes in our dataset.

# %%
print(dataset.classes)
# Out:
# ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# Now, visualize an instance from each class.

# %%
class_images = {}

for idx in range(len(dataset)):
    _, label = dataset[idx]
    if label not in class_images:
        class_images[label] = idx
    if len(class_images) == 10:
        break

fig, axes = plt.subplots(2, 5, figsize=(15, 6))

for i, (label, index) in enumerate(class_images.items()):
    image, _ = dataset[index]
    ax = axes[i//5, i%5]
    ax.imshow(image.squeeze(), cmap='gray')
    ax.set_title(dataset.classes[label])
    ax.axis('off')

plt.show()

# %% [markdown]
# ### Creating Training and Validation Datasets
#
# The `split_indices` function takes in the size of the entire dataset, `n`, the fraction of data to be used as validation set, `val_frac`, and the random seed and returns the indices of the data points to be added to the validation dataset.

# %%
def split_indices(n, val_frac, seed):
    # Determine the size of the validation set
    n_val = int(val_frac * n)
    np.random.seed(seed)
    # Create random permutation between 0 to n-1
    idxs = np.random.permutation(n)
    # Pick first n_val indices for validation set
    return idxs[n_val:], idxs[:n_val]

# %%
val_frac =  1/6
rand_seed = 42

train_indices, val_indices = split_indices(len(dataset), val_frac, rand_seed)
print("number of samples in training set: {}".format(len(train_indices)))
print("number of samples in validation set: {}".format(len(val_indices)))
# Out:
# number of samples in training set: 50000
# number of samples in validation set: 10000

# %% [markdown]
# Next, we make use of the built-in dataloaders in PyTorch to create iterables of our our training and validation sets. This helps in avoiding fitting the whole dataset into memory and only loads a batch of the data that we can decide.

# %%
# Import required packages
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data.dataloader import DataLoader

# %%
######################
#   YOUR CODE HERE   #
######################
batch_size = 64

# Training sampler and data loader
train_sampler = SubsetRandomSampler(train_indices)
train_dl = DataLoader(dataset,
                     batch_size,
                     sampler=train_sampler)

# Validation sampler and data loader
val_sampler = SubsetRandomSampler(val_indices)
val_dl = DataLoader(dataset,
                   batch_size,
                   sampler=val_sampler)

# %% [markdown]
# Plot images in a sample batch of data.

# %%
sample_batch = next(iter(train_dl))
grid = vutils.make_grid(sample_batch[0][:64], padding=2, normalize=True)
grid_transposed = np.transpose(grid, (1, 2, 0))
fig, ax = plt.subplots(figsize=(10, 10))
ax.imshow(grid_transposed)
ax.axis("off")
plt.show()

# %% [markdown]
# ### Building the Model
# Create your model by defining the network architecture in the `ImageClassifierNet` class.<br>
# **NOTE:** The number of parameters in your network must be $\leq$ 100,000.

# %%
# Import required packages
import torch.nn as nn
import torch.nn.functional as F
from torchinfo import summary

# %%
class ImageClassifierNet(nn.Module):
    def __init__(self, n_channels=1):
        super(ImageClassifierNet, self).__init__()
        self.conv1 = nn.Conv2d(in_channels=n_channels, out_channels=16, kernel_size=3, stride=1, padding=1)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(32 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)
        
    def forward(self, X):
        X = self.pool(F.relu(self.conv1(X)))
        X = self.pool(F.relu(self.conv2(X)))
        X = X.view(-1, 32 * 7 * 7)
        X = F.relu(self.fc1(X))
        X = self.fc2(X)
        return X

# %%
model = ImageClassifierNet()

# %% [markdown]
# The following code block prints your network architecture. It also shows the total number of parameters in your network (see `Total params`).
#
# **NOTE: The total number of parameters in your model should be <= 100,000.**

# %%
summary(model, input_size=(batch_size, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# ImageClassifierNet                       [64, 10]                  --
# ├─Conv2d: 1-1                            [64, 16, 28, 28]          160
# ├─MaxPool2d: 1-2                         [64, 16, 14, 14]          --
# ├─Conv2d: 1-3                            [64, 32, 14, 14]          4,640
# ├─MaxPool2d: 1-4                         [64, 32, 7, 7]            --
# ├─Linear: 1-5                            [64, 128]                 200,832
# ├─Linear: 1-6                            [64, 10]                  1,290
# ==========================================================================================
# Total params: 206,922
# Trainable params: 206,922
# Non-trainable params: 0
# Total mult-adds (M): 79.17
# ==========================================================================================
# Input size (MB): 0.20
# Forward/backward pass size (MB): 9.70
# Params size (MB): 0.83
# Estimated Total Size (MB): 10.73
# ==========================================================================================

# %% [markdown]
# ### Train the model
# Complete the `train_model` function to train your model on a dataset. Tune your network architecture and hyperparameters on the validation set.

# %%
def train_model(n_epochs, model, train_dl, val_dl, loss_fn, opt_fn, lr):
    """
    Trains the model on a dataset.
    
    Args:
        n_epochs: number of epochs
        model: ImageClassifierNet object
        train_dl: training dataloader
        val_dl: validation dataloader
        loss_fn: the loss function
        opt_fn: the optimizer
        lr: learning rate
    
    Returns:
        The trained model. 
        A tuple of (model, train_losses, val_losses, train_accuracies, val_accuracies)
    """
    metrics = {'train_losses': [], 'val_losses': [], 'train_accuracies': [], 'val_accuracies': []}
    optimizer = opt_fn(model.parameters(), lr=lr)
    
    for epoch in range(n_epochs):
        for phase in ['train', 'val']:
            if phase == 'train':
                model.train()
                data_loader = train_dl
            else:
                if not val_dl:
                    continue
                model.eval()
                data_loader = val_dl

            running_loss = 0.0
            correct_predictions = 0
            total_predictions = 0

            for X, y in data_loader:
                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == 'train'):
                    outputs = model(X)
                    loss = loss_fn(outputs, y)
                    if phase == 'train':
                        loss.backward()
                        optimizer.step()

                running_loss += loss.item() * X.size(0)
                _, predicted = torch.max(outputs.data, 1)
                total_predictions += y.size(0)
                correct_predictions += (predicted == y).sum().item()

            epoch_loss = running_loss / len(data_loader.dataset)
            epoch_accuracy = 100 * correct_predictions / total_predictions

            metrics[phase + '_losses'].append(epoch_loss)
            metrics[phase + '_accuracies'].append(epoch_accuracy)

            print(f"Epoch {epoch+1}/{n_epochs}, {phase.capitalize()} Loss: {epoch_loss:.4f}, {phase.capitalize()} Acc: {epoch_accuracy/100:.4f}")

    return model, metrics['train_losses'], metrics['val_losses'], metrics['train_accuracies'], metrics['val_accuracies']

# %%
import torch.optim as optim
num_epochs = 10  # Number of training epochs
loss_fn = nn.CrossEntropyLoss()  # Define the loss function
opt_fn = optim.Adam  # Select an optimizer
lr = 0.001  # Set the learning rate
model = ImageClassifierNet()

# %%
model, train_losses, val_losses, train_accuracies, val_accuracies = train_model(num_epochs, model, train_dl, val_dl, loss_fn, opt_fn, lr)
# Out:
# Epoch 1/10, Train Loss: 0.4146, Train Acc: 0.8214
# Epoch 1/10, Val Loss: 0.0590, Val Acc: 0.8713
# Epoch 2/10, Train Loss: 0.2642, Train Acc: 0.8871
# Epoch 2/10, Val Loss: 0.0494, Val Acc: 0.8912
# Epoch 3/10, Train Loss: 0.2258, Train Acc: 0.9019
# Epoch 3/10, Val Loss: 0.0544, Val Acc: 0.8790
# Epoch 4/10, Train Loss: 0.2013, Train Acc: 0.9112
# Epoch 4/10, Val Loss: 0.0439, Val Acc: 0.9038
# Epoch 5/10, Train Loss: 0.1817, Train Acc: 0.9192
# Epoch 5/10, Val Loss: 0.0414, Val Acc: 0.9114
# Epoch 6/10, Train Loss: 0.1646, Train Acc: 0.9278
# Epoch 6/10, Val Loss: 0.0407, Val Acc: 0.9119
# Epoch 7/10, Train Loss: 0.1501, Train Acc: 0.9332
# Epoch 7/10, Val Loss: 0.0409, Val Acc: 0.9110
# Epoch 8/10, Train Loss: 0.1355, Train Acc: 0.9402
# Epoch 8/10, Val Loss: 0.0416, Val Acc: 0.9147
# Epoch 9/10, Train Loss: 0.1209, Train Acc: 0.9452
# Epoch 9/10, Val Loss: 0.0426, Val Acc: 0.9124
# Epoch 10/10, Train Loss: 0.1107, Train Acc: 0.9516
# Epoch 10/10, Val Loss: 0.0405, Val Acc: 0.9179

# %% [markdown]
# ### Plot loss and accuracy

# %%
def plot_accuracy(train_accuracies, val_accuracies):
    """Plot accuracies"""
    plt.plot(train_accuracies, "-x")
    plt.plot(val_accuracies, "-o")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend(["Training", "Validation"])
    plt.title("Accuracy vs. No. of epochs")
    plt.grid(True,"both")
    plt.minorticks_on()
    plt.show()

def plot_losses(train_losses, val_losses):
    """Plot losses"""
    plt.plot(train_losses, "-x")
    plt.plot(val_losses, "-o")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend(["Training", "Validation"])
    plt.title("Loss vs. No. of Epochs")
    plt.grid(True,"both")
    plt.minorticks_on()
    plt.show()

# %%
plot_accuracy(train_accuracies, val_accuracies)
plot_losses(train_losses, val_losses)

# %% [markdown]
# ### Train a model on the entire dataset

# %%
indices, _ = split_indices(len(dataset), 0, rand_seed)

sampler = SubsetRandomSampler(indices)
dl = DataLoader(dataset, batch_size, sampler=sampler)

# %%
######################
#   YOUR CODE HERE   #
######################
num_epochs = 10 # Max number of training epochs
lr = 0.001# Set the learning rate

# %%
model, _, _, _, _ = train_model(num_epochs, model, dl, [], loss_fn, opt_fn, lr)
# Out:
# Epoch 1/10, Train Loss: 0.1429, Train Acc: 0.9483
# Epoch 2/10, Train Loss: 0.1230, Train Acc: 0.9551
# Epoch 3/10, Train Loss: 0.1076, Train Acc: 0.9611
# Epoch 4/10, Train Loss: 0.0957, Train Acc: 0.9650
# Epoch 5/10, Train Loss: 0.0843, Train Acc: 0.9697
# Epoch 6/10, Train Loss: 0.0736, Train Acc: 0.9727
# Epoch 7/10, Train Loss: 0.0639, Train Acc: 0.9768
# Epoch 8/10, Train Loss: 0.0577, Train Acc: 0.9792
# Epoch 9/10, Train Loss: 0.0490, Train Acc: 0.9820
# Epoch 10/10, Train Loss: 0.0429, Train Acc: 0.9840

# %% [markdown]
# ### Check Predictions
# Now, you should evaluate your model on dataset. Specifically, you should calculate the class probabilities for each image, and then visualize these probabilities along with the image itself. Please include a function `view_prediction` in your code that takes an image, its label, the calculated probabilities, and the list of class names as input, and plots the image along with the probabilities.

# %%
def view_prediction(image, label, probabilities, class_names):
    fig, ax = plt.subplots(1, 2, figsize=(15, 8))

    # Plot the image
    ax[0].imshow(image.squeeze(), cmap='gray')
    ax[0].set_title(f"Label: {class_names[label]}")
    ax[0].axis('off')

    # Plot the probabilities
    probabilities_df = pd.DataFrame({'class_names': class_names, 'probabilities': probabilities})
    sns.barplot(x='class_names', y='probabilities', data=probabilities_df, ax=ax[1])
    ax[1].set_ylim(0, 1)
    ax[1].set_title('Class Probabilities')
    ax[1].tick_params(axis='x', rotation=90)  # Rotate x-axis labels for readability
    
    plt.tight_layout()
    plt.show()

def get_predictions(dataset, model, idx):
    image, label = dataset[idx]
    with torch.no_grad():
        output = model(image.unsqueeze(0))
        probabilities = torch.nn.functional.softmax(output, dim=1).squeeze().numpy()
    return image.squeeze().numpy(), label, probabilities

# Use a list comprehension to get predictions for all sample indices
predictions = [get_predictions(dataset, model, idx) for idx in sample_indices]

# Use a loop to view all predictions
for image, label, probabilities in predictions:
    view_prediction(image, label, probabilities, dataset.classes)

# %% [markdown]
# ### Save the model

# %%
torch.save(model, 'model')

# %% [markdown]
# ### Calculate accuracy on the test set

# %%
test_dataset = FashionMNIST('MNIST_data/', download = True, train = False, transform = transform)
test_dl = DataLoader(test_dataset, batch_size)

# %%
def evaluate(model, test_dl):
    """
    Evaluates your model on the test data.
    
    Args:
        model: ImageClassifierNet object
        test_dl: test dataloader
    
    Returns: 
        Test accuracy.
    """
    correct_predictions = 0
    total_predictions = 0
    model.eval()
    for X, y in test_dl:
        with torch.no_grad():
            outputs = model(X)
            _, predicted = torch.max(outputs.data, 1)
            total_predictions += y.size(0)
            correct_predictions += (predicted == y).sum().item()
    return  correct_predictions / total_predictions

# %%
print("Test Accuracy = {:.4f}".format(evaluate(model, test_dl)))
# Out:
# Test Accuracy = 0.9110
